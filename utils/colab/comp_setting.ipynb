# %% [markdown]
# <a href="https://colab.research.google.com/github/UantumBear/Reinforce/blob/colab/utils/colab/comp_setting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

# 1. 비밀 공간에 저장한 토큰 꺼내오기
token = userdata.get('GITHUB_TOKEN')

# 2. 정보 입력
username = "UantumBear"
repo_name = "Reinforce"
email = "ninkyoii@gmail.com" # 커밋 기록용 이메일

# 3. 깃허브에서 프로젝트 다운로드 (Clone)
if not os.path.exists(repo_name):
    # 토큰을 주소 사이에 끼워넣어 인증 통과
    # !git clone https://{username}:{token}@github.com/{username}/{repo_name}.git

# 4. 폴더 안으로 이동 및 유저 설정
# %cd {repo_name}
# !git config --global user.email "{email}"
# !git config --global user.name "{username}"
# Out:
# Cloning into 'Reinforce'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 119 (delta 46), reused 112 (delta 39), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 534.27 KiB | 12.72 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/Reinforce

# %%
# 1. 먼저 내 프로젝트 폴더(Reinforce) 안으로 들어간다.
# %cd /content/Reinforce

# 1. 브랜치 생성 및 이동 (최초)
# !git checkout -b colab

# 1. 브랜치 이동 (루틴)
# !git checkout colab

# 2. git add 변경한 파일
# !git add utils/colab/test_add.py

# 3. git commit
# !git commit -m "colab 에서 repo 에 파일 add 테스트"

# 4. git push
# !git push origin colab
# Out:
# /content/Reinforce
# D	utils/colab/repo_clone.ipynb
# Already on 'colab'
# [colab ee9a620] colab 에서 repo 에 파일 add 테스트
#  1 file changed, 5 insertions(+)
#  create mode 100644 utils/colab/test_add.py
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (10/10), 1011 bytes | 1011.00 KiB/s, done.
# Total 10 (delta 4), reused 1 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# remote:
# remote: Create a pull request for 'colab' on GitHub by visiting:
# remote:      https://github.com/UantumBear/Reinforce/pull/new/colab
# remote:
# To https://github.com/UantumBear/Reinforce.git
#  * [new branch]      colab -> colab
